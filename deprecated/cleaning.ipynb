# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer, KNNImputer

# %%
# Manual imputer

data = pd.read_csv('Education_cleaning_test.csv')  # load data set

missing = []
categories = data.columns[5:].astype(int).values.reshape(-1,1)
row = data.iloc[21, :].values.reshape(-1,1)[5:]

imputer = SimpleImputer(strategy='mean')
imputer.fit(row, categories)
input_x = imputer.transform(row)
imputed_row = pd.DataFrame(input_x, categories)

print(row)
print(input_x)
plt.scatter(categories, row, color="red")
plt.scatter(categories, input_x,color="green")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <module>
#      10 imputer.fit(row, categories)
#      11 input_x = imputer.transform(row)
# ---> 12 imputed_row = pd.DataFrame(input_x, categories)
#      14 print(row)
#      15 print(input_x)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:695, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     685         mgr = dict_to_mgr(
#     686             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     687             # attribute "name"
#    (...)
#     692             typ=manager,
#     693         )
#     694     else:
# --> 695         mgr = ndarray_to_mgr(
#     696             data,
#     697             index,
#     698             columns,
#     699             dtype=dtype,
#     700             copy=copy,
#     701             typ=manager,
#     702         )
#     704 # For data is list-like, or Iterable (will consume into list)
#     705 elif is_list_like(data):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:347, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344     values = values.reshape(shape)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
#     351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:756, in _get_axes(N, K, index, columns)
#     754     index = default_index(N)
#     755 else:
# --> 756     index = ensure_index(index)
#     758 if columns is None:
#     759     columns = default_index(K)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:7043, in ensure_index(index_like, copy)
#    7041         return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7042 else:
# -> 7043     return Index._with_infer(index_like, copy=copy)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:680, in Index._with_infer(cls, *args, **kwargs)
#     678 with warnings.catch_warnings():
#     679     warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 680     result = cls(*args, **kwargs)
#     682 if result.dtype == _dtype_obj and not result._is_multi:
#     683     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685     # "ndarray[Any, Any]"
#     686     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:503, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     500             return cls(arr, dtype, copy=copy, name=name, **kwargs)
#     502 klass = cls._dtype_to_subclass(arr.dtype)
# --> 503 arr = klass._ensure_array(arr, dtype, copy)
#     504 disallow_kwargs(kwargs)
#     505 return klass._simple_new(arr, name)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/numeric.py:183, in NumericIndex._ensure_array(cls, data, dtype, copy)
#     179     subarr = data
#     181 if subarr.ndim > 1:
#     182     # GH#13601, GH#20285, GH#27125
# --> 183     raise ValueError("Index data must be 1-dimensional")
#     185 subarr = np.asarray(subarr)
#     186 return subarr
#
# ValueError: Index data must be 1-dimensional

# %%
test_data = pd.read_csv('Education_cleaning_test.csv')
# print(len(test_data))

categories = test_data.columns[5:].astype(int).values.reshape(-1,1)
print(categories)
# print(categories)
row = test_data.iloc[20, :].values.reshape(-1,1)[5:]
print('{{}{}{{}{')
print(test_data)
#numerical_test_data = test_data.drop(columns=categories, axis=1)
# print(numerical_test_data.head)

imputer = KNNImputer()
imputer.fit(numerical_test_data)

sample_incomplete_rows = test_data[test_data.isnull().any(axis=1)].head()

# transform the dataset to have the computed median
input_x = imputer.transform(numerical_test_data)
# creating the dataframe from the 2D numpy array
imputed_data = pd.DataFrame(input_x, columns=numerical_test_data.columns, index=numerical_test_data.index)

# # see what is imputed into the missing value cells
# print(imputed_data.loc[sample_incomplete_rows.index.values])
# print(numerical_test_data.head())
# print(imputed_data.head())

print(categories)
print(row)
# plt.scatter(categories, row )
# plt.scatter(missing, imputed_data, c='green')

# plt.show()
# Out:
# [[2005]
#  [2006]
#  [2007]
#  [2008]
#  [2009]
#  [2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]]
# {{}{}{{}{
#      Unnamed: 0 Country Name Country Code  \
# 0         38541       Canada          CAN
# 1         38542       Canada          CAN
# 2         38543       Canada          CAN
# 3         38763       Canada          CAN
# 4         38764       Canada          CAN
# ..          ...          ...          ...
# 103       88152        Niger          NER
# 104       88154        Niger          NER
# 105       88156        Niger          NER
# 106       88158        Niger          NER
# 107       88160        Niger          NER
#
#                                         Indicator Name     Indicator Code  \
# 0    Literacy rate, adult female (% of females ages...  SE.ADT.LITR.FE.ZS
# 1    Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 2    Literacy rate, adult total (% of people ages 1...     SE.ADT.LITR.ZS
# 3    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 4    Primary completion rate, male (% of relevant a...  SE.PRM.CMPT.MA.ZS
# ..                                                 ...                ...
# 103               School enrollment, primary (% gross)        SE.PRM.ENRR
# 104       School enrollment, primary, female (% gross)     SE.PRM.ENRR.FE
# 105         School enrollment, primary, male (% gross)     SE.PRM.ENRR.MA
# 106             School enrollment, secondary (% gross)        SE.SEC.ENRR
# 107     School enrollment, secondary, female (% gross)     SE.SEC.ENRR.FE
#
#           2005       2006       2007       2008       2009  ...       2011  \
# 0          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 1          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 2          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 3          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 4          NaN        NaN        NaN        NaN        NaN  ...        NaN
# ..         ...        ...        ...        ...        ...  ...        ...
# 103  48.356491  48.987259  51.379971  55.211430  59.011902  ...  66.518944
# 104  40.201191  41.032928  43.478840  48.024879  51.869930  ...  59.807110
# 105  56.208729  56.631790  58.979801  62.132099  65.896858  ...  72.998451
# 106   9.631490  11.048090  10.598790  10.913610  11.431990  ...  13.883270
# 107   7.448300   8.515430   8.124290   8.349410   8.746320  ...  11.066480
#
#           2012       2013       2014       2015       2016       2017  2018  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# ..         ...        ...        ...        ...        ...        ...   ...
# 103  68.394371  69.149223  69.575974  71.595909  73.432327  74.736198   NaN
# 104  62.064999  62.915508  63.750359  65.562927  67.525970  69.243080   NaN
# 105  74.508400  75.173462  75.208023  77.430672  79.146980  80.051918   NaN
# 106  15.059340  16.253820  18.204359  20.093220  23.124969  24.253750   NaN
# 107  12.296640  13.405330  15.337370  16.986280  19.816870  20.702129   NaN
#
#           2019  2020
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# 4          NaN   NaN
# ..         ...   ...
# 103  66.415413   NaN
# 104  62.008350   NaN
# 105  70.680290   NaN
# 106        NaN   NaN
# 107        NaN   NaN
#
# [108 rows x 21 columns]
# [[2005]
#  [2006]
#  [2007]
#  [2008]
#  [2009]
#  [2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]]
# [[101.310600280762]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [99.0333786010742]
#  [99.502082824707]
#  [100.287261962891]
#  [101.276412963867]
#  [101.421997070313]
#  [101.19637298584]
#  [101.343742370605]
#  [nan]]
